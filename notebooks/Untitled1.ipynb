# %%
pwd
# Out:
# 'C:\\Users\\DevendraP\\Desktop\\mlops2Copy\\simple-dvc-demo-main-mlflow\\simple-dvc-demo-main-mlflow'

# %%
import glob 
for i in glob.glob('C:\\Users\\DevendraP\\Desktop\\mlops2Copy\\simple-dvc-demo-main-mlflow\\simple-dvc-demo-main-mlflow\\*'):
    print(i)
# Out:
# C:\Users\DevendraP\Desktop\mlops2Copy\simple-dvc-demo-main-mlflow\simple-dvc-demo-main-mlflow\app.py
# C:\Users\DevendraP\Desktop\mlops2Copy\simple-dvc-demo-main-mlflow\simple-dvc-demo-main-mlflow\artifacts
# C:\Users\DevendraP\Desktop\mlops2Copy\simple-dvc-demo-main-mlflow\simple-dvc-demo-main-mlflow\build
# C:\Users\DevendraP\Desktop\mlops2Copy\simple-dvc-demo-main-mlflow\simple-dvc-demo-main-mlflow\data
# C:\Users\DevendraP\Desktop\mlops2Copy\simple-dvc-demo-main-mlflow\simple-dvc-demo-main-mlflow\data_given
# C:\Users\DevendraP\Desktop\mlops2Copy\simple-dvc-demo-main-mlflow\simple-dvc-demo-main-mlflow\dist
# C:\Users\DevendraP\Desktop\mlops2Copy\simple-dvc-demo-main-mlflow\simple-dvc-demo-main-mlflow\dvc.lock
# C:\Users\DevendraP\Desktop\mlops2Copy\simple-dvc-demo-main-mlflow\simple-dvc-demo-main-mlflow\dvc.yaml
# C:\Users\DevendraP\Desktop\mlops2Copy\simple-dvc-demo-main-mlflow\simple-dvc-demo-main-mlflow\mlflow.db
# ...

# %%
from src.get_data import read_params
import argparse
import mlflow
from mlflow.tracking import MlflowClient
from pprint import pprint
import joblib
import os

# %%
os.chdir("C://Users//DevendraP//Desktop//mlops2Copy//simple-dvc-demo-main-mlflow//simple-dvc-demo-main-mlflow//")

# %%
config = read_params("params.yaml")
mlflow_config = config["mlflow_config"]
experiment_name = mlflow_config["experiment_name"]
model_name = mlflow_config["registered_model_name"]
remote_server_uri = mlflow_config["remote_server_uri"]
mlflow.set_tracking_uri(remote_server_uri)
# experiment_id = mlflow.create_experiment(experiment_name)
# filter_string = ""
runs=mlflow.start_run(experiment_id=1)
# lowest = runs["metrics.mae"].sort_values(ascending=True)[0]
# lowest_run_id = runs[runs["metrics.mae"]==localhost]["run_id"][0]
client = MlflowClient()
for mv in client.search_model_versions_version(f"name='{model_name}'"):
    mv =dict(mv)
    pprint(mv,indent=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19672\3890490777.py in <module>
#       8 # filter_string = ""
#       9 runs=mlflow.start_run(experiment_id=1)
# ---> 10 lowest = runs["metrics.mae"].sort_values(ascending=True)[0]
#      11 lowest_run_id = runs[runs["metrics.mae"]==localhost]["run_id"][0]
#      12 client = MlflowClient()
#
# TypeError: 'ActiveRun' object is not subscriptable

# %%
runs.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19672\1007903347.py in <module>
# ----> 1 runs.head(10)
#
# AttributeError: 'ActiveRun' object has no attribute 'head'

# %%
lowest = runs["metrics.mae"].sort_values(ascending=True)[0]
lowest_run_id = runs[runs["metrics.mae"]==localhost]["run_id"][0]
client = MlflowClient()
for mv in client.search_model_versions_version(f"name='{model_name}'"):
    mv =dict(mv)
    pprint(mv,indent=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19672\2956445955.py in <module>
# ----> 1 lowest = runs["metrics.mae"].sort_values(ascending=True)[0]
#       2 lowest_run_id = runs[runs["metrics.mae"]==localhost]["run_id"][0]
#       3 client = MlflowClient()
#       4 for mv in client.search_model_versions_version(f"name='{model_name}'"):
#       5     mv =dict(mv)
#
# NameError: name 'runs' is not defined

# %%
HTTPConnectionPool(host='0.0.0.0', port=1234): Max retries exceeded with url: /api/2.0/mlflow/experiments/create (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001D6088DD7F0>: Failed to establish a new connection: [WinError 10049] The requested address is not valid in its context')

# %%
log_production_model("params.yaml")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\.conda\envs\mpipe\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     174             conn = connection.create_connection(
# --> 175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# ~\.conda\envs\mpipe\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# ~\.conda\envs\mpipe\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# OSError: [WinError 10049] The requested address is not valid in its context
#
# ...

# %%
# !ls
# Out:
# mlruns	schema_in.json	Untitled1.ipynb  Untitled.ipynb

# %%
experiment_name = "ElasticNet tregression"
experiment_id = mlflow.create_experiment(experiment_name)
mlflow.start_run(experiment_id=experiment_id)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\.conda\envs\mpipe\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     174             conn = connection.create_connection(
# --> 175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# ~\.conda\envs\mpipe\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# ~\.conda\envs\mpipe\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# OSError: [WinError 10049] The requested address is not valid in its context
#
# ...

# %%
import mlflow

# Create an experiment and log two runs under it
experiment_name = "Social NLP"
experiment_id = mlflow.create_experiment(experiment_name)
filter_string = ""
with mlflow.start_run(experiment_id=experiment_id,filter_string=filter_string):
    mlflow.log_metric("m", 1.55)
    mlflow.set_tag("s.release", "1.1.0-RC")
with mlflow.start_run(experiment_id=experiment_id):
    mlflow.log_metric("m", 2.50)
    mlflow.set_tag("s.release", "1.2.0-GA")

# Search for all the runs in the experiment with the given experiment ID
df = mlflow.search_runs([experiment_id], order_by=["metrics.m DESC"])
print(df[["metrics.m", "tags.s.release", "run_id"]])
print("--")

# Search the experiment_id using a filter_string with tag
# that has a case insensitive pattern
filter_string = "tags.s.release ILIKE '%rc%'"
df = mlflow.search_runs([experiment_id], filter_string=filter_string)
print(df[["metrics.m", "tags.s.release", "run_id"]])
print("--")

# Search for all the runs in the experiment with the given experiment name
df = mlflow.search_runs(experiment_names=["Social NLP"], order_by=["metrics.m DESC"])
print(df[["metrics.m", "tags.s.release", "run_id"]])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\.conda\envs\mpipe\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     174             conn = connection.create_connection(
# --> 175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# ~\.conda\envs\mpipe\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# ~\.conda\envs\mpipe\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# OSError: [WinError 10049] The requested address is not valid in its context
#
# ...
